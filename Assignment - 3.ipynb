# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the Dataset

# %%
df = pd.read_csv("C:/Users/moham/Downloads/penguins_size.csv")
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %% [markdown]
# ## Performing Visualization

# %% [markdown]
# ## Univariate

# %%
sns.distplot(df['body_mass_g'])
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_8988\2151326810.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['body_mass_g'])
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
plt.pie(df.island.value_counts(), [0,0.05,0.1], labels=['Dream', 'Torgersen', 'Biscoe'], autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## Bivariate

# %%
sns.lineplot(x=df['culmen_length_mm'], y=df['body_mass_g'])
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(x=df['culmen_length_mm'], y=df['culmen_depth_mm'])
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='culmen_depth_mm'>

# %% [markdown]
# ## Multivariate

# %%
sns.pairplot(df)
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Descriptive statistics

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# ## Missing Values

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
df = pd.read_csv("C:/Users/moham/Downloads/penguins_size.csv")
df['culmen_length_mm'] = df['culmen_length_mm'].fillna(df['culmen_length_mm'].median())
df['culmen_depth_mm'] = df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].median())
df['flipper_length_mm'] = df['flipper_length_mm'].fillna(df['flipper_length_mm'].median())
df['body_mass_g'] = df['body_mass_g'].fillna(df['body_mass_g'].median())
df['sex'] = df['sex'].fillna(df['sex'].mode())
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen             39.10             18.7              181.0
# 1    Adelie  Torgersen             39.50             17.4              186.0
# 2    Adelie  Torgersen             40.30             18.0              195.0
# 3    Adelie  Torgersen             44.45             17.3              197.0
# 4    Adelie  Torgersen             36.70             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe             44.45             17.3              197.0
# 340  Gentoo     Biscoe             46.80             14.3              215.0
# 341  Gentoo     Biscoe             50.40             15.7              222.0
# 342  Gentoo     Biscoe             45.20             14.8              212.0
# 343  Gentoo     Biscoe             49.90             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm     False
# culmen_depth_mm      False
# flipper_length_mm    False
# body_mass_g          False
# sex                   True
# dtype: bool

# %% [markdown]
# ## Outlier Detection

# %%
sns.boxplot(df['culmen_length_mm'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['culmen_depth_mm'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['flipper_length_mm'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['body_mass_g'])
# Out:
# <Axes: >

# %% [markdown]
# #### No outliers were detected in any of the variables

# %% [markdown]
# ## Correlation of independent variables with target

# %%
df1 = df.drop(['species','island','sex'], axis=1)
df1.corr()
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.235000           0.655858
# culmen_depth_mm           -0.235000         1.000000          -0.583832
# flipper_length_mm          0.655858        -0.583832           1.000000
# body_mass_g                0.594925        -0.471942           0.871221
#
#                    body_mass_g
# culmen_length_mm      0.594925
# culmen_depth_mm      -0.471942
# flipper_length_mm     0.871221
# body_mass_g           1.000000

# %% [markdown]
# ## Correlation along with Categorical columns using encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df2 = df
df2['species'] = le.fit_transform(df['species'])
df2['island'] = le.fit_transform(df['island'])
df2['sex'] = le.fit_transform(df['sex'])
df2
# Out:
#      species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0          0       2             39.10             18.7              181.0
# 1          0       2             39.50             17.4              186.0
# 2          0       2             40.30             18.0              195.0
# 3          0       2             44.45             17.3              197.0
# 4          0       2             36.70             19.3              193.0
# ..       ...     ...               ...              ...                ...
# 339        2       0             44.45             17.3              197.0
# 340        2       0             46.80             14.3              215.0
# 341        2       0             50.40             15.7              222.0
# 342        2       0             45.20             14.8              212.0
# 343        2       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# ...

# %%
df.corr()
# Out:
#                     species    island  culmen_length_mm  culmen_depth_mm  \
# species            1.000000 -0.635659          0.728706        -0.741282
# island            -0.635659  1.000000         -0.351189         0.567701
# culmen_length_mm   0.728706 -0.351189          1.000000        -0.235000
# culmen_depth_mm   -0.741282  0.567701         -0.235000         1.000000
# flipper_length_mm  0.850819 -0.562957          0.655858        -0.583832
# body_mass_g        0.747547 -0.558500          0.594925        -0.471942
# sex               -0.010379  0.043476          0.265490         0.317521
#
#                    flipper_length_mm  body_mass_g       sex
# species                     0.850819     0.747547 -0.010379
# island                     -0.562957    -0.558500  0.043476
# culmen_length_mm            0.655858     0.594925  0.265490
# culmen_depth_mm            -0.583832    -0.471942  0.317521
# flipper_length_mm           1.000000     0.871221  0.189194
# ...

# %% [markdown]
# ## Splitting Independent and Dependent variables

# %%
Y = df['species']
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    2
# 340    2
# 341    2
# 342    2
# 343    2
# Name: species, Length: 344, dtype: int32

# %%
X = df.drop(['species'], axis=1)
X
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0         2             39.10             18.7              181.0
# 1         2             39.50             17.4              186.0
# 2         2             40.30             18.0              195.0
# 3         2             44.45             17.3              197.0
# 4         2             36.70             19.3              193.0
# ..      ...               ...              ...                ...
# 339       0             44.45             17.3              197.0
# 340       0             46.80             14.3              215.0
# 341       0             50.40             15.7              222.0
# 342       0             45.20             14.8              212.0
# 343       0             49.90             16.1              213.0
#
#      body_mass_g  sex
# 0         3750.0    2
# 1         3800.0    1
# 2         3250.0    1
# 3         4050.0    3
# 4         3450.0    1
# ..           ...  ...
# ...

# %% [markdown]
# ## Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale = MinMaxScaler()

# %%
X_scaled = pd.DataFrame(scale.fit_transform(X), columns=X.columns)
X_scaled
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0       1.0          0.254545         0.666667           0.152542
# 1       1.0          0.269091         0.511905           0.237288
# 2       1.0          0.298182         0.583333           0.389831
# 3       1.0          0.449091         0.500000           0.423729
# 4       1.0          0.167273         0.738095           0.355932
# ..      ...               ...              ...                ...
# 339     0.0          0.449091         0.500000           0.423729
# 340     0.0          0.534545         0.142857           0.728814
# 341     0.0          0.665455         0.309524           0.847458
# 342     0.0          0.476364         0.202381           0.677966
# 343     0.0          0.647273         0.357143           0.694915
#
#      body_mass_g       sex
# 0       0.291667  0.666667
# 1       0.305556  0.333333
# 2       0.152778  0.333333
# 3       0.375000  1.000000
# 4       0.208333  0.333333
# ...

# %% [markdown]
# ## Splitting into Training and Testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X_scaled, Y, test_size=0.3, random_state=10)

# %%
X_train
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 258     0.0          0.432727         0.059524           0.610169
# 332     0.0          0.414545         0.250000           0.694915
# 121     1.0          0.203636         0.797619           0.440678
# 61      0.0          0.334545         0.952381           0.389831
# 70      1.0          0.050909         0.702381           0.305085
# ..      ...               ...              ...                ...
# 123     1.0          0.338182         0.642857           0.508475
# 320     0.0          0.596364         0.226190           0.796610
# 15      1.0          0.163636         0.559524           0.220339
# 125     1.0          0.309091         0.702381           0.457627
# 265     0.0          0.418182         0.095238           0.762712
#
#      body_mass_g       sex
# 258     0.458333  0.333333
# 332     0.541667  0.333333
# 121     0.222222  0.666667
# 61      0.472222  0.666667
# 70      0.250000  0.333333
# ...

# %%
X_test
# Out:
#      island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 229     0.0          0.534545         0.273810           0.728814
# 80      1.0          0.090909         0.488095           0.288136
# 327     0.0          0.774545         0.321429           0.796610
# 6       1.0          0.247273         0.559524           0.152542
# 309     0.0          0.727273         0.464286           0.983051
# ..      ...               ...              ...                ...
# 211     0.5          0.490909         0.750000           0.372881
# 311     0.0          0.730909         0.476190           0.949153
# 19      1.0          0.505455         1.000000           0.372881
# 270     0.0          0.527273         0.130952           0.644068
# 194     0.5          0.683636         0.714286           0.406780
#
#      body_mass_g       sex
# 229     0.680556  0.666667
# 80      0.138889  0.333333
# 327     0.777778  0.666667
# 6       0.256944  0.333333
# 309     0.791667  0.666667
# ...

# %% [markdown]
# ## Checking the shape of the training and testing data

# %%
X_train.shape
# Out:
# (240, 6)

# %%
X_test.shape
# Out:
# (104, 6)

# %%
Y_train.shape
# Out:
# (240,)

# %%
Y_test.shape
# Out:
# (104,)
